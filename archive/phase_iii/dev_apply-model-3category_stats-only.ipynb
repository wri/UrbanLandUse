# %% [markdown]
# # Development: Applying 3-Category Classifier
# Direct application of existing model to series of images for series of cities, strictly in order to generate statistics (rather than generate comprehensive maps).
#
# Date: 2018-12-06
# Author: Taufiq Rashid, Peter Kerins

# %% [markdown]
# ### Import statements
# (may be over-inclusive)

# %%
# typical, comprehensive imports
import warnings
warnings.filterwarnings('ignore')
#
import os
import sys
import json
import itertools
import pickle
from pprint import pprint
#
import numpy as np
import shapely
import cartopy
import geojson
import fiona
import gdal
import h5py
get_ipython().magic(u'matplotlib inline')
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import StandardScaler 
import ogr, gdal
from keras.models import load_model
import math
from keras.utils import to_categorical
from keras.models import load_model
from keras import models
from keras import layers
from keras.layers import Dropout
from keras.utils import to_categorical
from skimage import measure
from skimage import filters
from scipy import stats

import tensorflow as tf

import keras
import keras.backend as K
from keras.models import Model
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Input, Add, Lambda
from keras.callbacks import EarlyStopping, ModelCheckpoint, History

import collections

import descarteslabs as dl
print dl.places.find('illinois') ## TEST

ULU_REPO = os.environ["ULU_REPO"]
sys.path.append(ULU_REPO+'/utils')
# sys.path.append('/home/Peter.Kerins/UrbanLandUse/utils')
print sys.path

import util_descartes
import util_ml
import util_rasters
import util_vectors
import util_workflow
import util_keras
# Out:
# Using TensorFlow backend.
# [{u'name': u'Illinois', u'id': 85688697, u'placetype': u'region', u'bbox': [-91.512974, 36.970298, -87.019935, 42.508302], u'path': u'continent:north-america_country:united-states_region:illinois', u'slug': u'north-america_united-states_illinois'}]
# ['', '/usr/lib/python2.7', '/usr/lib/python2.7/plat-x86_64-linux-gnu', '/usr/lib/python2.7/lib-tk', '/usr/lib/python2.7/lib-old', '/usr/lib/python2.7/lib-dynload', '/home/Taufiq.Rashid/.local/lib/python2.7/site-packages', '/usr/local/lib/python2.7/dist-packages', '/usr/lib/python2.7/dist-packages', '/usr/lib/python2.7/dist-packages/PILcompat', '/usr/lib/python2.7/dist-packages/gtk-2.0', '/usr/local/lib/python2.7/dist-packages/IPython/extensions', '/home/Taufiq.Rashid/.ipython', '/home/Peter.Kerins/UrbanLandUse/utils']

# %% [markdown]
# ### Set key variables

# %%
data_root='/data/phase_iii/'

bands=['blue','green','red','nir','swir1','swir2','alpha']; suffix='BGRNS1S2A'  # S2, Lx
resolution= 5  # Lx:15 S2:10

ndvi_bands = ['raw'];

# ground truth source: aue, aue+osm, aue+osm2
label_suffix = 'aue'

# NYU AoUE land use/land cover categories
category_label = {0:'Open Space',1:'Non-Residential',\
                   2:'Residential Atomistic',3:'Residential Informal Subdivision',\
                   4:'Residential Formal Subdivision',5:'Residential Housing Project',\
                   6:'Roads',7:'Study Area',8:'Labeled Study Area',254:'No Data',255:'No Label'}

# %% [markdown]
# ### Set input stack and model parameters

# %%
window = 17    # width of square window

bands_vir=bands[:-1]
bands_sar=None
bands_ndvi=ndvi_bands
bands_ndbi=None
bands_osm=None

unflatten_input = True # is the model a cnn?

# %%
stat_tuples = []

model_id = '3cat_Hin_U-AB'
notes = 'application of ' + model_id + ' to an outsample image from insample city'
place_images = {}
place_images['hindupur'] = ['AC','AR','AV','L']
stat_tuples.append((model_id, notes, place_images))

model_id = '3cat_Mal_V-Z'
notes = 'application of ' + model_id + ' to an outsample image from insample city'
place_images = {}
place_images['malegaon'] = ['A','AA','BA','K']
stat_tuples.append((model_id, notes, place_images))

model_id = '3cat_Pun_P-Q+S-U'
notes = 'application of ' + model_id + ' to an outsample image from insample city'
place_images = {}
place_images['pune'] = ['A','AT','F','V']
stat_tuples.append((model_id, notes, place_images))

model_id = '3cat_Ahm_V-AA'
notes = 'application of ' + model_id + ' to an outsample image from insample city'
place_images = {}
place_images['ahmedabad'] = ['A','AB','BN','I']
stat_tuples.append((model_id, notes, place_images))

model_id = '3cat_Sit_Q-R+T-V'
notes = 'application of ' + model_id + ' to an outsample image from insample city'
place_images = {}
place_images['sitapur'] = ['AS','BB','G','W']
stat_tuples.append((model_id, notes, place_images))

model_id = '3cat_Sin_O-U'
notes = 'application of ' + model_id + ' to an outsample image from insample city'
place_images = {}
place_images['singrauli'] = ['AW','BG','G','V']
stat_tuples.append((model_id, notes, place_images))

# %%
reload(util_workflow)
for stat_tuple in stat_tuples:
    util_workflow.apply_model_to_data_3category(
        stat_tuple[0], stat_tuple[1], stat_tuple[2], 
        data_root, resolution, window, 
            bands_vir=bands_vir,
            bands_sar=None, bands_ndvi=bands_ndvi, bands_ndbi=None, bands_osm=None,
            label_suffix='aue',
            unflatten_input=True )
# Out:
# /data/phase_iii/hindupur/hindupur_train_aue_vir+ndvi_17w_AC_5m.pkl
# /data/phase_iii/hindupur/hindupur_valid_aue_vir+ndvi_17w_AC_5m.pkl
# (84212, 2023) (84212,) (36092, 2023) (36092,)
# (84212, 2023) (36092, 2023)
# (84212, 2023) (36092, 2023)
# (84212, 7, 17, 17)
# (84212,)
# (84212,)
# evaluate training
# 0 38590
# 1 8355
# 2 28662
# [[36659   788  1143]
#  [   87  8255    13]
#  [  501   201 27960]]
# 75607 72874 0.9638525533350086
# evaluate validation
# 0 16490
# 1 3560
# 2 12234
# [[15341   425   724]
#  [   78  3449    33]
#  [  427   120 11687]]
# 32284 30477 0.9440280014868047
# /data/phase_iii/hindupur/hindupur_train_aue_vir+ndvi_17w_AR_5m.pkl
# /data/phase_iii/hindupur/hindupur_valid_aue_vir+ndvi_17w_AR_5m.pkl
# (84212, 2023) (84212,) (36092, 2023) (36092,)
# (84212, 2023) (36092, 2023)
# (84212, 2023) (36092, 2023)
# (84212, 7, 17, 17)
# (84212,)
# (84212,)
# evaluate training
# 0 38590
# 1 8355
# 2 28662
# [[31581  1985  5024]
#  [ 1448  5152  1755]
#  [ 3435  1410 23817]]
# 75607 60550 0.8008517729839829
# evaluate validation
# 0 16490
# 1 3560
# 2 12234
# [[13475   845  2170]
#  [  623  2187   750]
#  [ 1409   589 10236]]
# 32284 25898 0.802193036798414
# /data/phase_iii/hindupur/hindupur_train_aue_vir+ndvi_17w_AV_5m.pkl
# /data/phase_iii/hindupur/hindupur_valid_aue_vir+ndvi_17w_AV_5m.pkl
# (84212, 2023) (84212,) (36092, 2023) (36092,)
# (84212, 2023) (36092, 2023)
# (84212, 2023) (36092, 2023)
# (84212, 7, 17, 17)
# (84212,)
# (84212,)
# evaluate training
# 0 38590
# 1 8355
# 2 28662
# [[34093  1308  3189]
#  [  820  6928   607]
#  [ 2232   657 25773]]
# 75607 66794 0.8834367188223312
# evaluate validation
# 0 16490
# 1 3560
# 2 12234
# [[14391   636  1463]
#  [  390  2878   292]
#  [ 1035   300 10899]]
# 32284 28168 0.8725065047701648
# /data/phase_iii/hindupur/hindupur_train_aue_vir+ndvi_17w_L_5m.pkl
# /data/phase_iii/hindupur/hindupur_valid_aue_vir+ndvi_17w_L_5m.pkl
# (84212, 2023) (84212,) (36092, 2023) (36092,)
# (84212, 2023) (36092, 2023)
# (84212, 2023) (36092, 2023)
# (84212, 7, 17, 17)
# (84212,)
# (84212,)
# evaluate training
# 0 38590
# 1 8355
# 2 28662
# [[31884  2656  4050]
#  [  899  6314  1142]
#  [ 2818   818 25026]]
# 75607 63224 0.8362188686232757
# evaluate validation
# 0 16490
# 1 3560
# 2 12234
# [[13588  1089  1813]
#  [  440  2636   484]
#  [ 1217   391 10626]]
# 32284 26850 0.8316813282121175
# /data/phase_iii/malegaon/malegaon_train_aue_vir+ndvi_17w_A_5m.pkl
# /data/phase_iii/malegaon/malegaon_valid_aue_vir+ndvi_17w_A_5m.pkl
# (208677, 2023) (208677,) (89434, 2023) (89434,)
# (208677, 2023) (89434, 2023)
# (208677, 2023) (89434, 2023)
# (208677, 7, 17, 17)
# (208677,)
# (208677,)
# evaluate training
# 0 85660
# 1 36128
# 2 61154
# [[73467  6219  5974]
#  [ 4153 27986  3989]
#  [ 3870  5549 51735]]
# 182942 153188 0.8373582884192804
# evaluate validation
# 0 36622
# 1 15615
# 2 26214
# [[31219  2714  2689]
#  [ 1821 12050  1744]
#  [ 1800  2480 21934]]
# 78451 65203 0.831130259652522
# /data/phase_iii/malegaon/malegaon_train_aue_vir+ndvi_17w_AA_5m.pkl
# /data/phase_iii/malegaon/malegaon_valid_aue_vir+ndvi_17w_AA_5m.pkl
# (208677, 2023) (208677,) (89434, 2023) (89434,)
# (208677, 2023) (89434, 2023)
# (208677, 2023) (89434, 2023)
# (208677, 7, 17, 17)
# (208677,)
# (208677,)
# evaluate training
# 0 85660
# 1 36128
# 2 61154
# [[77421  3550  4689]
#  [  951 33222  1955]
#  [ 1002   697 59455]]
# 182942 170098 0.9297919559204557
# evaluate validation
# 0 36622
# 1 15615
# 2 26214
# [[32539  1821  2262]
#  [  585 13974  1056]
#  [  655   418 25141]]
# 78451 71654 0.9133599316770978
# /data/phase_iii/malegaon/malegaon_train_aue_vir+ndvi_17w_BA_5m.pkl
# /data/phase_iii/malegaon/malegaon_valid_aue_vir+ndvi_17w_BA_5m.pkl
# (208677, 2023) (208677,) (89434, 2023) (89434,)
# (208677, 2023) (89434, 2023)
# (208677, 2023) (89434, 2023)
# (208677, 7, 17, 17)
# (208677,)
# (208677,)
# evaluate training
# 0 85660
# 1 36128
# 2 61154
# [[73864  5683  6113]
#  [ 2751 31111  2266]
#  [ 2899  3429 54826]]
# 182942 159801 0.873506357206109
# evaluate validation
# 0 36622
# 1 15615
# 2 26214
# [[31353  2543  2726]
#  [ 1295 13223  1097]
#  [ 1440  1624 23150]]
# 78451 67726 0.8632904615619941
# /data/phase_iii/malegaon/malegaon_train_aue_vir+ndvi_17w_K_5m.pkl
# /data/phase_iii/malegaon/malegaon_valid_aue_vir+ndvi_17w_K_5m.pkl
# (208677, 2023) (208677,) (89434, 2023) (89434,)
# (208677, 2023) (89434, 2023)
# (208677, 2023) (89434, 2023)
# (208677, 7, 17, 17)
# (208677,)
# (208677,)
# evaluate training
# 0 85660
# 1 36128
# 2 61154
# [[69641  7583  8436]
#  [ 2072 28049  6007]
#  [ 1962  3151 56041]]
# 182942 153731 0.8403264422603886
# evaluate validation
# 0 36622
# 1 15615
# 2 26214
# [[29365  3479  3778]
#  [  962 11945  2708]
#  [  968  1482 23764]]
# 78451 65074 0.8294859211482326
# /data/phase_iii/pune/pune_train_aue_vir+ndvi_17w_A_5m.pkl
# /data/phase_iii/pune/pune_valid_aue_vir+ndvi_17w_A_5m.pkl
# (223921, 2023) (223921,) (95967, 2023) (95967,)
# (223921, 2023) (95967, 2023)
# (223921, 2023) (95967, 2023)
# (223921, 7, 17, 17)
# (223921,)
# (223921,)
# evaluate training
# 0 61492
# 1 53473
# 2 76055
# [[53675  3703  4114]
#  [ 4342 41820  7311]
#  [ 1159   848 74048]]
# 191020 169543 0.8875667469374935
# evaluate validation
# 0 26488
# 1 22758
# 2 32585
# [[22809  1758  1921]
#  [ 1956 17615  3187]
#  [  589   404 31592]]
# 81831 72016 0.8800576798523787
# /data/phase_iii/pune/pune_train_aue_vir+ndvi_17w_AT_5m.pkl
# /data/phase_iii/pune/pune_valid_aue_vir+ndvi_17w_AT_5m.pkl
# (223921, 2023) (223921,) (95967, 2023) (95967,)
# (223921, 2023) (95967, 2023)
# (223921, 2023) (95967, 2023)
# (223921, 7, 17, 17)
# (223921,)
# (223921,)
# evaluate training
# 0 61492
# 1 53473
# 2 76055
# [[55937  2354  3201]
#  [ 4115 46157  3201]
#  [ 1238  1179 73638]]
# 191020 175732 0.9199664956549053
# evaluate validation
# 0 26488
# 1 22758
# 2 32585
# [[23875  1103  1510]
#  [ 1878 19335  1545]
#  [  605   598 31382]]
# 81831 74592 0.9115371925065073
# /data/phase_iii/pune/pune_train_aue_vir+ndvi_17w_F_5m.pkl
# /data/phase_iii/pune/pune_valid_aue_vir+ndvi_17w_F_5m.pkl
# (223921, 2023) (223921,) (95967, 2023) (95967,)
# (223921, 2023) (95967, 2023)
# (223921, 2023) (95967, 2023)
# (223921, 7, 17, 17)
# (223921,)
# (223921,)
# evaluate training
# 0 61492
# 1 53473
# 2 76055
# [[52778  4060  4654]
#  [ 3151 44219  6103]
#  [ 1349   978 73728]]
# 191020 170725 0.8937545806721809
# evaluate validation
# 0 26488
# 1 22758
# 2 32585
# [[22568  1847  2073]
#  [ 1423 18683  2652]
#  [  650   444 31491]]
# 81831 72742 0.8889296232479134
# /data/phase_iii/pune/pune_train_aue_vir+ndvi_17w_V_5m.pkl
# /data/phase_iii/pune/pune_valid_aue_vir+ndvi_17w_V_5m.pkl
# (223921, 2023) (223921,) (95967, 2023) (95967,)
# (223921, 2023) (95967, 2023)
# (223921, 2023) (95967, 2023)
# (223921, 7, 17, 17)
# (223921,)
# (223921,)
# evaluate training
# 0 61492
# 1 53473
# 2 76055
# [[57125  2592  1775]
#  [ 2036 49607  1830]
#  [ 1211   607 74237]]
# 191020 180969 0.9473824730394723
# evaluate validation
# 0 26488
# 1 22758
# 2 32585
# [[24230  1276   982]
#  [ 1038 20816   904]
#  [  667   334 31584]]
# 81831 76630 0.9364421796140827
# /data/phase_iii/ahmedabad/ahmedabad_train_aue_vir+ndvi_17w_A_5m.pkl
# /data/phase_iii/ahmedabad/ahmedabad_valid_aue_vir+ndvi_17w_A_5m.pkl
# (222200, 2023) (222200,) (95229, 2023) (95229,)
# (222200, 2023) (95229, 2023)
# (222200, 2023) (95229, 2023)
# (222200, 7, 17, 17)
# (222200,)
# (222200,)
# evaluate training
# 0 54063
# 1 40797
# 2 87747
# [[48214  3938  1911]
#  [ 2908 34925  2964]
#  [ 2018  1789 83940]]
# 182607 167079 0.9149649246743006
# evaluate validation
# 0 23144
# 1 17406
# 2 37539
# [[20409  1767   968]
#  [ 1295 14708  1403]
#  [  972   842 35725]]
# 78089 70842 0.9071956357489531
# /data/phase_iii/ahmedabad/ahmedabad_train_aue_vir+ndvi_17w_AB_5m.pkl
# /data/phase_iii/ahmedabad/ahmedabad_valid_aue_vir+ndvi_17w_AB_5m.pkl
# (222200, 2023) (222200,) (95229, 2023) (95229,)
# (222200, 2023) (95229, 2023)
# (222200, 2023) (95229, 2023)
# (222200, 7, 17, 17)
# (222200,)
# (222200,)
# evaluate training
# 0 54063
# 1 40797
# 2 87747
# [[52145   988   930]
#  [  420 39793   584]
#  [ 1000   644 86103]]
# 182607 178041 0.9749954821009053
# evaluate validation
# 0 23144
# 1 17406
# 2 37539
# [[21958   602   584]
#  [  308 16708   390]
#  [  581   395 36563]]
# 78089 75229 0.9633751232567968
# /data/phase_iii/ahmedabad/ahmedabad_train_aue_vir+ndvi_17w_BN_5m.pkl
# /data/phase_iii/ahmedabad/ahmedabad_valid_aue_vir+ndvi_17w_BN_5m.pkl
# (222200, 2023) (222200,) (95229, 2023) (95229,)
# (222200, 2023) (95229, 2023)
# (222200, 2023) (95229, 2023)
# (222200, 7, 17, 17)
# (222200,)
# (222200,)
# evaluate training
# 0 54063
# 1 40797
# 2 87747
# [[47400  3672  2991]
#  [ 1996 36336  2465]
#  [ 1667  1752 84328]]
# 182607 168064 0.9203590223813983
# evaluate validation
# 0 23144
# 1 17406
# 2 37539
# [[20111  1621  1412]
#  [  861 15383  1162]
#  [  791   823 35925]]
# 78089 71419 0.9145846406023895
# /data/phase_iii/ahmedabad/ahmedabad_train_aue_vir+ndvi_17w_I_5m.pkl
# /data/phase_iii/ahmedabad/ahmedabad_valid_aue_vir+ndvi_17w_I_5m.pkl
# (222200, 2023) (222200,) (95229, 2023) (95229,)
# (222200, 2023) (95229, 2023)
# (222200, 2023) (95229, 2023)
# (222200, 7, 17, 17)
# (222200,)
# (222200,)
# evaluate training
# 0 54063
# 1 40797
# 2 87747
# [[48531  2819  2713]
#  [ 1706 36408  2683]
#  [ 1673  1127 84947]]
# 182607 169886 0.9303367340791974
# evaluate validation
# 0 23144
# 1 17406
# 2 37539
# [[20599  1339  1206]
#  [  833 15295  1278]
#  [  794   563 36182]]
# 78089 72076 0.922998117532559
# /data/phase_iii/sitapur/sitapur_train_aue_vir+ndvi_17w_AS_5m.pkl
# /data/phase_iii/sitapur/sitapur_valid_aue_vir+ndvi_17w_AS_5m.pkl
# (120785, 2023) (120785,) (51766, 2023) (51766,)
# (120785, 2023) (51766, 2023)
# (120785, 2023) (51766, 2023)
# (120785, 7, 17, 17)
# (120785,)
# (120785,)
# evaluate training
# 0 49593
# 1 17843
# 2 40909
# [[40639  4542  4412]
#  [ 3160 12086  2597]
#  [ 2634  5465 32810]]
# 108345 85535 0.7894688264340763
# evaluate validation
# 0 21144
# 1 7756
# 2 17584
# [[17310  1953  1881]
#  [ 1374  5246  1136]
#  [ 1180  2479 13925]]
# 46484 36481 0.7848076757594011
# /data/phase_iii/sitapur/sitapur_train_aue_vir+ndvi_17w_BB_5m.pkl
# /data/phase_iii/sitapur/sitapur_valid_aue_vir+ndvi_17w_BB_5m.pkl
# (120785, 2023) (120785,) (51766, 2023) (51766,)
# (120785, 2023) (51766, 2023)
# (120785, 2023) (51766, 2023)
# (120785, 7, 17, 17)
# (120785,)
# (120785,)
# evaluate training
# 0 49593
# 1 17843
# 2 40909
# [[41178  4304  4111]
#  [  834 15284  1725]
#  [ 1166  1575 38168]]
# 108345 94630 0.8734136323780516
# evaluate validation
# 0 21144
# 1 7756
# 2 17584
# [[17381  1922  1841]
#  [  429  6493   834]
#  [  547   722 16315]]
# 46484 40189 0.8645770587729111
# /data/phase_iii/sitapur/sitapur_train_aue_vir+ndvi_17w_G_5m.pkl
# /data/phase_iii/sitapur/sitapur_valid_aue_vir+ndvi_17w_G_5m.pkl
# (120785, 2023) (120785,) (51766, 2023) (51766,)
# (120785, 2023) (51766, 2023)
# (120785, 2023) (51766, 2023)
# (120785, 7, 17, 17)
# (120785,)
# (120785,)
# evaluate training
# 0 49593
# 1 17843
# 2 40909
# [[42334  3835  3424]
#  [ 1345 14364  2134]
#  [ 2105  1027 37777]]
# 108345 94475 0.8719830172135309
# evaluate validation
# 0 21144
# 1 7756
# 2 17584
# [[17923  1704  1517]
#  [  677  6067  1012]
#  [  986   447 16151]]
# 46484 40141 0.863544445400568
# /data/phase_iii/sitapur/sitapur_train_aue_vir+ndvi_17w_W_5m.pkl
# /data/phase_iii/sitapur/sitapur_valid_aue_vir+ndvi_17w_W_5m.pkl
# (120785, 2023) (120785,) (51766, 2023) (51766,)
# (120785, 2023) (51766, 2023)
# (120785, 2023) (51766, 2023)
# (120785, 7, 17, 17)
# (120785,)
# (120785,)
# evaluate training
# 0 49593
# 1 17843
# 2 40909
# [[43674  2885  3034]
#  [ 1447 14347  2049]
#  [ 2614  1242 37053]]
# 108345 95074 0.8775116525912594
# evaluate validation
# 0 21144
# 1 7756
# 2 17584
# [[18541  1272  1331]
#  [  721  6066   969]
#  [ 1227   580 15777]]
# 46484 40384 0.8687720505980553
# /data/phase_iii/singrauli/singrauli_train_aue_vir+ndvi_17w_AW_5m.pkl
# /data/phase_iii/singrauli/singrauli_valid_aue_vir+ndvi_17w_AW_5m.pkl
# (132100, 2023) (132100,) (56615, 2023) (56615,)
# (132100, 2023) (56615, 2023)
# (132100, 2023) (56615, 2023)
# (132100, 7, 17, 17)
# (132100,)
# (132100,)
# evaluate training
# 0 71230
# 1 23493
# 2 24133
# [[51397  9487 10346]
#  [ 3343 17354  2796]
#  [ 2415   952 20766]]
# 118856 89517 0.7531550784142155
# evaluate validation
# 0 30710
# 1 10057
# 2 10335
# [[21975  4196  4539]
#  [ 1427  7442  1188]
#  [ 1104   397  8834]]
# 51102 38251 0.7485225627177019
# /data/phase_iii/singrauli/singrauli_train_aue_vir+ndvi_17w_BG_5m.pkl
# /data/phase_iii/singrauli/singrauli_valid_aue_vir+ndvi_17w_BG_5m.pkl
# (132100, 2023) (132100,) (56615, 2023) (56615,)
# (132100, 2023) (56615, 2023)
# (132100, 2023) (56615, 2023)
# (132100, 7, 17, 17)
# (132100,)
# (132100,)
# evaluate training
# 0 71230
# 1 23493
# 2 24133
# [[54579  6276 10375]
#  [ 2489 19204  1800]
#  [ 1038   863 22232]]
# 118856 96015 0.8078262771757421
# evaluate validation
# 0 30710
# 1 10057
# 2 10335
# [[23355  2885  4470]
#  [ 1127  8079   851]
#  [  496   410  9429]]
# 51102 40863 0.7996360220735
# /data/phase_iii/singrauli/singrauli_train_aue_vir+ndvi_17w_G_5m.pkl
# /data/phase_iii/singrauli/singrauli_valid_aue_vir+ndvi_17w_G_5m.pkl
# (132100, 2023) (132100,) (56615, 2023) (56615,)
# (132100, 2023) (56615, 2023)
# (132100, 2023) (56615, 2023)
# (132100, 7, 17, 17)
# (132100,)
# (132100,)
# evaluate training
# 0 71230
# 1 23493
# 2 24133
# [[56896  6429  7905]
#  [ 1562 20890  1041]
#  [  767   623 22743]]
# 118856 100529 0.8458050077404591
# evaluate validation
# 0 30710
# 1 10057
# 2 10335
# [[24310  2899  3501]
#  [  724  8834   499]
#  [  419   266  9650]]
# 51102 42794 0.8374231928300262
# /data/phase_iii/singrauli/singrauli_train_aue_vir+ndvi_17w_V_5m.pkl
# /data/phase_iii/singrauli/singrauli_valid_aue_vir+ndvi_17w_V_5m.pkl
# (132100, 2023) (132100,) (56615, 2023) (56615,)
# (132100, 2023) (56615, 2023)
# (132100, 2023) (56615, 2023)
# (132100, 7, 17, 17)
# (132100,)
# (132100,)
# evaluate training
# 0 71230
# 1 23493
# 2 24133
# [[58051  4154  9025]
#  [ 2793 18917  1783]
#  [  888   631 22614]]
# 118856 99582 0.8378373830517601
# evaluate validation
# 0 30710
# 1 10057
# 2 10335
# [[24757  1950  4003]
#  [ 1253  8065   739]
#  [  440   312  9583]]
# 51102 42405 0.8298109663026887
