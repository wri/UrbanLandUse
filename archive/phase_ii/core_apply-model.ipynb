# %% [markdown]
# # Core Workflow: Applying Model
# Load existing, trained model from file and apply it to imagery (and other inputs) in order to generate a comprehensive LULC raster covering the entire urban extent of a given city. Allows user to preview LULC tiles and compare against VIR component of input stack.
#
# Date: 2018-09-17
# Author: Peter Kerins

# %% [markdown]
# ### Import statements
# (may be over-inclusive)

# %%
# typical, comprehensive imports
import warnings
warnings.filterwarnings('ignore')
#
import os
import sys
import json
import itertools
import pickle
from pprint import pprint
#
import numpy as np
import shapely
import cartopy
import geojson
import fiona
import gdal
import h5py
get_ipython().magic(u'matplotlib inline')
import matplotlib.pyplot as plt
import sklearn
from sklearn.preprocessing import StandardScaler 
import ogr, gdal
from keras.models import load_model
import math
from keras.utils import to_categorical
from keras.models import load_model
from keras import models
from keras import layers
from keras.layers import Dropout
from keras.utils import to_categorical
from skimage import measure
from skimage import filters
from scipy import stats

import tensorflow as tf
import keras

import collections

import descarteslabs as dl
print dl.places.find('illinois') ## TEST

ULU_REPO = os.environ["ULU_REPO"]
sys.path.append(ULU_REPO+'/utils')
print sys.path

import util_descartes
import util_ml
import util_rasters
import util_vectors
import util_workflow
# Out:
# Using TensorFlow backend.
# [{u'name': u'Illinois', u'id': 85688697, u'placetype': u'region', u'bbox': [-91.512974, 36.970298, -87.019935, 42.508302], u'path': u'continent:north-america_country:united-states_region:illinois', u'slug': u'north-america_united-states_illinois'}]
# ['', '/usr/lib/python2.7', '/usr/lib/python2.7/plat-x86_64-linux-gnu', '/usr/lib/python2.7/lib-tk', '/usr/lib/python2.7/lib-old', '/usr/lib/python2.7/lib-dynload', '/home/Peter.Kerins/.local/lib/python2.7/site-packages', '/usr/local/lib/python2.7/dist-packages', '/usr/lib/python2.7/dist-packages', '/usr/lib/python2.7/dist-packages/PILcompat', '/usr/lib/python2.7/dist-packages/gtk-2.0', '/usr/local/lib/python2.7/dist-packages/IPython/extensions', '/home/Peter.Kerins/.ipython', '/home/Peter.Kerins/UrbanLandUse/utils']

# %% [markdown]
# ### Set key variables

# %%
place = 'hyderabad'

data_root='/data/phase_iii/'
data_path=data_root+place+'/'

bands=['blue','green','red','nir','swir1','swir2','alpha']; suffix='BGRNS1S2A'  # S2, Lx
resolution=10  # Lx:15 S2:10

s1_bands=['vv','vh']; s1_suffix='VVVH'
s1_resolution = resolution

tile_resolution = resolution
tile_size = 256
tile_pad = 16

# NYU AoUE land use/land cover categories
category_label = {0:'Open Space',1:'Non-Residential',\
                   2:'Residential Atomistic',3:'Residential Informal Subdivision',\
                   4:'Residential Formal Subdivision',5:'Residential Housing Project',\
                   6:'Roads',7:'Study Area',8:'Labeled Study Area',254:'No Data',255:'No Label'}

# %% [markdown]
# ### Load and inspect study area

# %%
print place, place.title() # capitalized version of place name
place_title = place.title()
place_shapefile = data_path+place_title+"_studyAreaEPSG4326.shp"

util_vectors.info_studyareas(data_path, place)

shape = util_vectors.load_shape(place_shapefile)
polygon = shape['geometry']['coordinates']
#print polygon
#pprint(shape)
place_bbox = shape['bbox']
#print bbox

# using Albers projection
lonlat_crs = cartopy.crs.PlateCarree()
clat, clon = (place_bbox[0]+place_bbox[2])/2.0, (place_bbox[1]+place_bbox[3])/2.0
print "center co-ordinates", clat, clon
albers = cartopy.crs.AlbersEqualArea(central_latitude=clat, central_longitude=clon)

# visualize Study Region
fig = plt.figure(figsize=(6,6))
ax = plt.subplot(projection=albers) # Specify projection of the map here
shp = shapely.geometry.shape(shape['geometry'])
ax.add_geometries([shp], lonlat_crs)
ax.set_extent((place_bbox[0], place_bbox[2], place_bbox[1], place_bbox[3]), crs=lonlat_crs)
ax.gridlines(crs=lonlat_crs)
plt.show()
# Out:
# hyderabad Hyderabad
# >>> ogrinfo -al -so /data/phase_iii/hyderabad/Hyderabad_studyArea.shp
# INFO: Open of `/data/phase_iii/hyderabad/Hyderabad_studyArea.shp'
#       using driver `ESRI Shapefile' successful.
#
# Layer name: Hyderabad_studyArea
# Metadata:
#   DBF_DATE_LAST_UPDATE=2016-07-17
# Geometry: Polygon
# Feature Count: 1
# Extent: (195959.428255, 1900659.020753) - (262570.313581, 1963477.496879)
# Layer SRS WKT:
# PROJCS["WGS_1984_UTM_Zone_44N",
#     GEOGCS["GCS_WGS_1984",
#         DATUM["WGS_1984",
#             SPHEROID["WGS_84",6378137.0,298.257223563]],
#         PRIMEM["Greenwich",0.0],
#         UNIT["Degree",0.0174532925199433]],
#     PROJECTION["Transverse_Mercator"],
#     PARAMETER["false_easting",500000.0],
#     PARAMETER["false_northing",0.0],
#     PARAMETER["central_meridian",81.0],
#     PARAMETER["scale_factor",0.9996],
#     PARAMETER["latitude_of_origin",0.0],
#     UNIT["Meter",1.0]]
# Id: Integer (6.0)
#
# >>> ogrinfo -al -so /data/phase_iii/hyderabad/Hyderabad_studyAreaEPSG4326.shp
# INFO: Open of `/data/phase_iii/hyderabad/Hyderabad_studyAreaEPSG4326.shp'
#       using driver `ESRI Shapefile' successful.
#
# Layer name: Hyderabad_studyAreaEPSG4326
# Metadata:
#   DBF_DATE_LAST_UPDATE=2018-01-23
# Geometry: Polygon
# Feature Count: 1
# Extent: (78.137220, 17.172900) - (78.766320, 17.740540)
# Layer SRS WKT:
# GEOGCS["GCS_WGS_1984",
#     DATUM["WGS_1984",
#         SPHEROID["WGS_84",6378137,298.257223563]],
#     PRIMEM["Greenwich",0],
#     UNIT["Degree",0.017453292519943295]]
# Id: Integer (6.0)
#
# simple polygon
# center co-ordinates 78.45177 17.45672

# %% [markdown]
# ### Generate tiles

# %%
tiles = dl.raster.dltiles_from_shape(tile_resolution, tile_size, tile_pad, shape)
single_tile_id = 22
highlights = {single_tile_id:'green'}
util_vectors.draw_tiled_area(shape, tiles, albers, lonlat_crs, highlights=highlights)
# Out:
# number of tiles to cover region 458
# [u'geometry', u'type', u'properties']
# tile022 {u'type': u'Polygon', u'coordinates': [[[78.1775006012039, 17.529165535205387], [78.20460181878519, 17.52954978485592], [78.20420289377427, 17.555551127046854], [78.17709782110293, 17.55516627151902], [78.1775006012039, 17.529165535205387]]]}

# %% [markdown]
# ### Set input stack and model parameters

# %%
window = 17    # width of square window

bands_vir=bands[:-1]
bands_sar=s1_bands
bands_ndvi=None
bands_ndbi=None
bands_osm=None

haze_removal = False

image_suffix = 'P'

model_id = 'cnn_demo_1'
unflatten_input = True # is the model a cnn?
n_cats = 4 # number of categories

# %%
stack_label, feature_count = util_workflow.build_stack_label(
        bands_vir=bands_vir,
        bands_sar=bands_sar,
        bands_ndvi=bands_ndvi,
        bands_ndbi=bands_ndbi,
        bands_osm=bands_osm,)
print stack_label, feature_count
# Out:
# vir+sar 8

# %% [markdown]
# ### Load model objects

# %%
scaler_filename = data_root+'models/'+model_id+'_scaler.pkl'
#model_filename  = data_root+'models/'+model_id+'_SVM.pkl'
network_filename = data_root+'models/'+model_id+'_DLv3.hd5'

with open(scaler_filename, "rb") as f:
    scaler = pickle.load(f)
f.close()

#with open(model_filename, "rb") as f:
#    model = pickle.load(f)
#f.close()

network = load_model(network_filename)

# %% [markdown]
# ### Apply model
# We can apply a model in at least two ways. One, we can do a limited application of the model, and classify only those pixels for which we have ground-truth in order to quantitatively assess the quality of the model's predictions, anywhere we have ground-truth. Two, we can use it to classify every pixel in every tile in order to generate a comprehensive LULC raster, for any city for which we have imagery (and any other necessary remote sensing inputs). And of course, we can do both.

# %% [markdown]
# ### Use model to generate performance statistics

# %% [markdown]
# Assign application-specific variables

# %%
label_suffix = 'aue'

cats_map = {}
cats_map[0] = 0
cats_map[1] = 1
cats_map[2] = 4
cats_map[3] = 4
cats_map[4] = 4
cats_map[5] = 4
cats_map[6] = 6

notes = 'test use of new scorecard functionality'

# %% [markdown]
# Load the samples of interest. Just as when training a model, this dataset can be constructed from one or more images of one or more cities.

# %%
place_images = {}
place_images['hyderabad'] = ['P']

X_train_raw, Y_train_raw, X_valid_raw, Y_valid_raw = util_workflow.load_datasets(place_images, data_root, label_suffix, stack_label, window)
# Out:
# calculate total size of training and validation supersets
# /data/phase_iii/hyderabad/hyderabad_train_aue_vir+sar_17w_P.pkl
# /data/phase_iii/hyderabad/hyderabad_valid_aue_vir+sar_17w_P.pkl
# (55922, 2312) (55922,) (23967, 2312) (23967,)
# 55922 23967
# construct np arrays for supersets
# populate superset np arrays
# /data/phase_iii/hyderabad/hyderabad_train_aue_vir+sar_17w_P.pkl
# /data/phase_iii/hyderabad/hyderabad_valid_aue_vir+sar_17w_P.pkl
# (55922, 2312) (55922,) (23967, 2312) (23967,)
# (55922, 2312) (55922,)

# %% [markdown]
# Prepare data for model ingestion. This process is contingent on what model is being applied and what taxonomy that model employs.

# %%
X_train_raw_scaled, X_valid_raw_scaled, scaler = util_ml.scale_learning_data(X_train_raw, X_valid_raw)
# Out:
# (55922, 2312) (23967, 2312)

# %%
X_train = X_train_raw_scaled.reshape((X_train_raw_scaled.shape[0],feature_count,window,window))
X_valid = X_valid_raw_scaled.reshape((X_valid_raw_scaled.shape[0],feature_count,window,window))

# %%
Y_train = Y_train_raw.copy()
Y_valid = Y_valid_raw.copy()

for k, v in cats_map.items():
    Y_train[Y_train_raw==k] = v
    Y_valid[Y_valid_raw==k] = v

# %%
Y_t = Y_train.copy()
Y_v = Y_valid.copy()

Y_t[Y_train==0] = 0
Y_t[Y_train==1] = 1
Y_t[Y_train==4] = 2
Y_t[Y_train==6] = 3

Y_v[Y_valid==0] = 0
Y_v[Y_valid==1] = 1
Y_v[Y_valid==4] = 2
Y_v[Y_valid==6] = 3

categories_reduced = [0,1,2,3]

#Y_t_cat = to_categorical(Y_t)
#Y_v_cat = to_categorical(Y_v)

# %% [markdown]
# Now apply model to prepared data and store results

# %%
reload(util_workflow)

print "evaluate training"
Yhat_t_prob = network.predict(X_train)
Yhat_t = Yhat_t_prob.argmax(axis=-1)
train_confusion = util_ml.calc_confusion(Yhat_t,Y_t,categories_reduced)
train_recalls, train_precisions, train_accuracy = util_ml.calc_confusion_details(train_confusion)

print "evaluate validation"
Yhat_v_prob = network.predict(X_valid)
Yhat_v = Yhat_v_prob.argmax(axis=-1)
valid_confusion = util_ml.calc_confusion(Yhat_v,Y_v,categories_reduced)
valid_recalls, valid_precisions, valid_accuracy = util_ml.calc_confusion_details(valid_confusion)

util_workflow.record_model_application(
        model_id, notes, place_images, label_suffix, resolution, stack_label, feature_count, window, cats_map, 
        train_confusion, train_recalls, train_precisions, train_accuracy, 
        valid_confusion, valid_recalls, valid_precisions, valid_accuracy)
# Out:
# evaluate training
# 0 15360
# 1 12300
# 2 20497
# 3 7765
# [[12938   935  1382   105]
#  [  453 10443  1214   190]
#  [  168    85 20203    41]
#  [  812  1266  4521  1166]]
# 55922 44750 0.8002217374199778
# evaluate validation
# 0 6656
# 1 5216
# 2 8701
# 3 3394
# [[5403  483  723   47]
#  [ 295 4247  594   80]
#  [ 108   81 8484   28]
#  [ 356  601 2011  426]]
# 23967 18560 0.7743981307631327

# %% [markdown]
# ### Use model to generate comprehensive LULC raster

# %%
reload(util_workflow)
util_workflow.classify_tiles(data_path, place, tiles, image_suffix,
        window, stack_label, feature_count, model_id, scaler, network, n_cats,
        bands_vir=bands_vir,
        bands_sar=bands_sar, bands_ndvi=None, bands_ndbi=None, bands_osm=None,
        haze_removal=False, unflatten_input=unflatten_input)
# Out:
# Feature count: 8
# Stack label:  vir+sar
# tile 0 load VIR image
# vir shape: (7, 288, 288)
# 5569 study area within image
# 82944 full extent of image
# vir band 0 into imn band 0 ( 0.0 - 0.1954 )
# vir band 1 into imn band 1 ( 0.0 - 0.2049 )
# vir band 2 into imn band 2 ( 0.0 - 0.2203 )
# vir band 3 into imn band 3 ( 0.0 - 0.4345 )
# vir band 4 into imn band 4 ( 0.0 - 0.2772 )
# vir band 5 into imn band 5 ( 0.0 - 0.215 )
# tile 0 load SAR image
# sar shape: (2, 288, 288)
# sar band 0 into imn band 6 ( 0.0 - 1.0 )
# sar band 1 into imn band 7 ( 0.0 - 1.0 )
# imn (8, 288, 288) 8
# imn.shape, Y.shape (8, 288, 288) (288, 288)
# nz 65536
# .....................done
# 0 64989
# 1 485
# 3 62
# 254 17408
# /data/phase_iii/hyderabad/maps/hyderabad_tile000_cnn_demo_1_lulc_P.tif
# Y_full sample [1.0000000e+00 2.3071576e-25 2.4225989e-32 4.1670504e-14 0.0000000e+00
#  1.0000000e+00]
# tile 0 done
# tile 1 load VIR image
# vir shape: (7, 288, 288)
# 34215 study area within image
# 82944 full extent of image
# vir band 0 into imn band 0 ( 0.0 - 0.2752 )
# vir band 1 into imn band 1 ( 0.0 - 0.259 )
# vir band 2 into imn band 2 ( 0.0 - 0.2859 )
# vir band 3 into imn band 3 ( 0.0 - 0.4259 )
# vir band 4 into imn band 4 ( 0.0 - 0.3775 )
# vir band 5 into imn band 5 ( 0.0 - 0.3412 )
# tile 1 load SAR image
# sar shape: (2, 288, 288)
# sar band 0 into imn band 6 ( 0.0 - 1.0 )
# sar band 1 into imn band 7 ( 0.0 - 1.0 )
# imn (8, 288, 288) 8
# imn.shape, Y.shape (8, 288, 288) (288, 288)
# nz 65536
# .....................done
# 0 63359
# 1 2043
# 3 134
# 254 17408
# /data/phase_iii/hyderabad/maps/hyderabad_tile001_cnn_demo_1_lulc_P.tif
# Y_full sample [1.0000000e+00 2.3071576e-25 2.4225989e-32 4.1670504e-14 0.0000000e+00
#  1.0000000e+00]
# tile 1 done
# tile 2 load VIR image
# vir shape: (7, 288, 288)
# 27575 study area within image
# 82944 full extent of image
# vir band 0 into imn band 0 ( 0.0 - 0.1947 )
# vir band 1 into imn band 1 ( 0.0 - 0.193 )
# vir band 2 into imn band 2 ( 0.0 - 0.201 )
# vir band 3 into imn band 3 ( 0.0 - 0.3764 )
# vir band 4 into imn band 4 ( 0.0 - 0.3385 )
# vir band 5 into imn band 5 ( 0.0 - 0.2274 )
# tile 2 load SAR image
# sar shape: (2, 288, 288)
# sar band 0 into imn band 6 ( 0.0 - 1.0 )
# sar band 1 into imn band 7 ( 0.0 - 1.0 )
# imn (8, 288, 288) 8
# imn.shape, Y.shape (8, 288, 288) (288, 288)
# nz 65536
# .....................done
# 0 63744
# 1 1318
# 2 436
# 3 38
# 254 17408
# /data/phase_iii/hyderabad/maps/hyderabad_tile002_cnn_demo_1_lulc_P.tif
# Y_full sample [1.0000000e+00 2.3071576e-25 2.4225989e-32 4.1670504e-14 0.0000000e+00
#  1.0000000e+00]
# tile 2 done
# tile 3 load VIR image
# vir shape: (7, 288, 288)
# 29409 study area within image
# 82944 full extent of image
# vir band 0 into imn band 0 ( 0.0 - 0.3105 )
# vir band 1 into imn band 1 ( 0.0 - 0.3352 )
# vir band 2 into imn band 2 ( 0.0 - 0.3797 )
# vir band 3 into imn band 3 ( 0.0 - 0.4182 )
# vir band 4 into imn band 4 ( 0.0 - 0.4501 )
# vir band 5 into imn band 5 ( 0.0 - 0.3918 )
# tile 3 load SAR image
# sar shape: (2, 288, 288)
# sar band 0 into imn band 6 ( 0.0 - 1.0 )
# sar band 1 into imn band 7 ( 0.0 - 1.0 )
# imn (8, 288, 288) 8
# imn.shape, Y.shape (8, 288, 288) (288, 288)
# nz 65536
# .....................done
# 0 62810
# 1 2562
# 2 1
# 3 163
# 254 17408
# /data/phase_iii/hyderabad/maps/hyderabad_tile003_cnn_demo_1_lulc_P.tif
# Y_full sample [1.0000000e+00 2.3071576e-25 2.4225989e-32 4.1670504e-14 0.0000000e+00
#  1.0000000e+00]
# tile 3 done
# tile 4 load VIR image
# vir shape: (7, 288, 288)
# 30748 study area within image
# 82944 full extent of image
# vir band 0 into imn band 0 ( 0.0 - 0.2991 )
# vir band 1 into imn band 1 ( 0.0 - 0.3055 )
# vir band 2 into imn band 2 ( 0.0 - 0.3348 )
# vir band 3 into imn band 3 ( 0.0 - 0.4031 )
# vir band 4 into imn band 4 ( 0.0 - 0.4844 )
# vir band 5 into imn band 5 ( 0.0 - 0.4642 )
# tile 4 load SAR image
# sar shape: (2, 288, 288)
# sar band 0 into imn band 6 ( 0.0 - 1.0 )
# sar band 1 into imn band 7 ( 0.0 - 1.0 )
# imn (8, 288, 288) 8
# imn.shape, Y.shape (8, 288, 288) (288, 288)
# nz 65536
# .....................done
# 0 63041
# 1 2271
# 2 70
# 3 154
# 254 17408
# /data/phase_iii/hyderabad/maps/hyderabad_tile004_cnn_demo_1_lulc_P.tif
# Y_full sample [1.0000000e+00 2.3071576e-25 2.4225989e-32 4.1670504e-14 0.0000000e+00
#  1.0000000e+00]
# tile 4 done
# tile 5 load VIR image
# vir shape: (7, 288, 288)
# 4569 study area within image
# 82944 full extent of image
# vir band 0 into imn band 0 ( 0.0 - 0.1541 )
# vir band 1 into imn band 1 ( 0.0 - 0.1731 )
# vir band 2 into imn band 2 ( 0.0 - 0.2297 )
# vir band 3 into imn band 3 ( 0.0 - 0.4345 )
# vir band 4 into imn band 4 ( 0.0 - 0.2689 )
# vir band 5 into imn band 5 ( 0.0 - 0.1922 )
# tile 5 load SAR image
# sar shape: (2, 288, 288)
# sar band 0 into imn band 6 ( 0.0 - 1.0 )
# sar band 1 into imn band 7 ( 0.0 - 1.0 )
# imn (8, 288, 288) 8
# imn.shape, Y.shape (8, 288, 288) (288, 288)
# nz 65536
# .....................done
# 0 65351
# 1 163
# 3 22
# 254 17408
# /data/phase_iii/hyderabad/maps/hyderabad_tile005_cnn_demo_1_lulc_P.tif
# Y_full sample [1.0000000e+00 2.3071576e-25 2.4225989e-32 4.1670504e-14 0.0000000e+00
#  1.0000000e+00]
# tile 5 done
# tile 6 load VIR image
# vir shape: (7, 288, 288)
# 73576 study area within image
# 82944 full extent of image
# vir band 0 into imn band 0 ( 0.0 - 0.2752 )
# vir band 1 into imn band 1 ( 0.0 - 0.2665 )
# vir band 2 into imn band 2 ( 0.0 - 0.3245 )
# vir band 3 into imn band 3 ( 0.0 - 0.4259 )
# vir band 4 into imn band 4 ( 0.0 - 0.6818 )
# vir band 5 into imn band 5 ( 0.0 - 0.7201 )
# tile 6 load SAR image
# sar shape: (2, 288, 288)
# sar band 0 into imn band 6 ( 0.0 - 1.0 )
# sar band 1 into imn band 7 ( 0.0 - 1.0 )
# imn (8, 288, 288) 8
# imn.shape, Y.shape (8, 288, 288) (288, 288)
# nz 65536
# .....................done
# 0 53260
# 1 10610
# 2 1259
# 3 407
# 254 17408
# /data/phase_iii/hyderabad/maps/hyderabad_tile006_cnn_demo_1_lulc_P.tif
# Y_full sample [8.5845494e-01 1.2669476e-02 3.9300453e-04 1.2848261e-01 0.0000000e+00
#  8.5845494e-01]
# tile 6 done
# tile 7 load VIR image
# vir shape: (7, 288, 288)
# 78122 study area within image
# 82944 full extent of image
# vir band 0 into imn band 0 ( 0.0 - 0.2305 )
# vir band 1 into imn band 1 ( 0.0 - 0.2355 )
# vir band 2 into imn band 2 ( 0.0 - 0.2776 )
# vir band 3 into imn band 3 ( 0.0 - 0.4233 )
# vir band 4 into imn band 4 ( 0.0 - 0.4164 )
# vir band 5 into imn band 5 ( 0.0 - 0.8648 )
# tile 7 load SAR image
# sar shape: (2, 288, 288)
# sar band 0 into imn band 6 ( 0.0 - 1.0 )
# sar band 1 into imn band 7 ( 0.0 - 1.0 )
# imn (8, 288, 288) 8
# imn.shape, Y.shape (8, 288, 288) (288, 288)
# nz 65536
# .....................done
# 0 55535
# 1 7909
# 2 1787
# 3 305
# 254 17408
# /data/phase_iii/hyderabad/maps/hyderabad_tile007_cnn_demo_1_lulc_P.tif
# Y_full sample [1.2091517e-01 8.2324064e-01 1.6298966e-04 5.5681273e-02 1.0000000e+00
#  8.2324064e-01]
# tile 7 done
# tile 8 load VIR image
# vir shape: (7, 288, 288)
# 49858 study area within image
# 82944 full extent of image
# vir band 0 into imn band 0 ( 0.0 - 0.3551 )
# vir band 1 into imn band 1 ( 0.0 - 0.3726 )
# vir band 2 into imn band 2 ( 0.0 - 0.4348 )
# vir band 3 into imn band 3 ( 0.0 - 0.4998 )
# vir band 4 into imn band 4 ( 0.0 - 0.4604 )
# vir band 5 into imn band 5 ( 0.0 - 0.4655 )
# tile 8 load SAR image
# sar shape: (2, 288, 288)
# sar band 0 into imn band 6 ( 0.0 - 1.0 )
# sar band 1 into imn band 7 ( 0.0 - 1.0 )
# imn (8, 288, 288) 8
# imn.shape, Y.shape (8, 288, 288) (288, 288)
# nz 65536
# .....................done
# 0 52920
# 1 11189
# 2 1012
# 3 415
# 254 17408
# /data/phase_iii/hyderabad/maps/hyderabad_tile008_cnn_demo_1_lulc_P.tif
# Y_full sample [1.0000000e+00 2.3071576e-25 2.4225989e-32 4.1670504e-14 0.0000000e+00
#  1.0000000e+00]
# tile 8 done
# tile 9 load VIR image
# vir shape: (7, 288, 288)
# 73864 study area within image
# 82944 full extent of image
# vir band 0 into imn band 0 ( 0.0 - 0.3215 )
# vir band 1 into imn band 1 ( 0.0 - 0.339 )
# vir band 2 into imn band 2 ( 0.0 - 0.4007 )
# vir band 3 into imn band 3 ( 0.0 - 0.4662 )
# vir band 4 into imn band 4 ( 0.0 - 0.5398 )
# vir band 5 into imn band 5 ( 0.0 - 0.6014 )
# tile 9 load SAR image
# sar shape: (2, 288, 288)
# sar band 0 into imn band 6 ( 0.0 - 1.0 )
# sar band 1 into imn band 7 ( 0.0 - 1.0 )
# imn (8, 288, 288) 8
# imn.shape, Y.shape (8, 288, 288) (288, 288)
# nz 65536
# .....................done
# 0 41398
# 1 20883
# 2 1767
# 3 1488
# 254 17408
# /data/phase_iii/hyderabad/maps/hyderabad_tile009_cnn_demo_1_lulc_P.tif
# Y_full sample [0.6090321  0.22366977 0.00656555 0.16073257 0.         0.6090321 ]
# tile 9 done
# tile 10 load VIR image
# vir shape: (7, 288, 288)
# 79046 study area within image
# 82944 full extent of image
# vir band 0 into imn band 0 ( 0.0 - 0.288 )
# vir band 1 into imn band 1 ( 0.0 - 0.303 )
# vir band 2 into imn band 2 ( 0.0 - 0.3293 )
# vir band 3 into imn band 3 ( 0.0 - 0.4489 )
# vir band 4 into imn band 4 ( 0.0 - 0.4472 )
# vir band 5 into imn band 5 ( 0.0 - 0.3882 )
# tile 10 load SAR image
# sar shape: (2, 288, 288)
# sar band 0 into imn band 6 ( 0.0 - 1.0 )
# sar band 1 into imn band 7 ( 0.0 - 1.0 )
# imn (8, 288, 288) 8
# imn.shape, Y.shape (8, 288, 288) (288, 288)
# nz 65536
# .....................done
# 0 51555
# 1 11288
# 2 1751
# 3 942
# 254 17408
# /data/phase_iii/hyderabad/maps/hyderabad_tile010_cnn_demo_1_lulc_P.tif
# Y_full sample [8.9356542e-01 2.0389659e-02 1.0344672e-04 8.5941479e-02 0.0000000e+00
#  8.9356542e-01]
# tile 10 done
# tile 11 load VIR image
# vir shape: (7, 288, 288)
# 12652 study area within image
# 82944 full extent of image
# vir band 0 into imn band 0 ( 0.0 - 0.2366 )
# vir band 1 into imn band 1 ( 0.0 - 0.2446 )
# vir band 2 into imn band 2 ( 0.0 - 0.2814 )
# vir band 3 into imn band 3 ( 0.0 - 0.3748 )
# vir band 4 into imn band 4 ( 0.0 - 0.3945 )
# vir band 5 into imn band 5 ( 0.0 - 0.324 )
# tile 11 load SAR image
# sar shape: (2, 288, 288)
# sar band 0 into imn band 6 ( 0.0 - 1.0 )
# sar band 1 into imn band 7 ( 0.0 - 1.0 )
# imn (8, 288, 288) 8
# imn.shape, Y.shape (8, 288, 288) (288, 288)
# nz 65536
# .....................done
# 0 65326
# 1 207
# 3 3
# 254 17408
# /data/phase_iii/hyderabad/maps/hyderabad_tile011_cnn_demo_1_lulc_P.tif
# Y_full sample [1.0000000e+00 2.3071576e-25 2.4225989e-32 4.1670504e-14 0.0000000e+00
#  1.0000000e+00]
# tile 11 done
# tile 12 load VIR image
# vir shape: (7, 288, 288)
# 7988 study area within image
# 82944 full extent of image
# vir band 0 into imn band 0 ( 0.0 - 0.1978 )
# vir band 1 into imn band 1 ( 0.0 - 0.2038 )
# vir band 2 into imn band 2 ( 0.0 - 0.2124 )
# vir band 3 into imn band 3 ( 0.0 - 0.4104 )
# vir band 4 into imn band 4 ( 0.0 - 0.3419 )
# vir band 5 into imn band 5 ( 0.0 - 0.2532 )
# tile 12 load SAR image
# sar shape: (2, 288, 288)
# sar band 0 into imn band 6 ( 0.0 - 1.0 )
# sar band 1 into imn band 7 ( 0.0 - 1.0 )
# imn (8, 288, 288) 8
# imn.shape, Y.shape (8, 288, 288) (288, 288)
# nz 65536
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-c43fac647245> in <module>()
#       4         bands_vir=bands_vir,
#       5         bands_sar=bands_sar, bands_ndvi=None, bands_ndbi=None, bands_osm=None,
# ----> 6         haze_removal=False, unflatten_input=unflatten_input)
#
# /home/Peter.Kerins/UrbanLandUse/utils/util_workflow.pyc in classify_tiles(data_path, place, tiles, image_suffix, window, stack_label, feature_count, model_id, scaler, model, n_cats, bands_vir, bands_sar, bands_ndvi, bands_ndbi, bands_osm, haze_removal, unflatten_input)
#     662         Y, Y_deep, Y_max = create_classification_arrays(window, n_cats, imn, tiles['features'][tile_id]['properties']['pad'])
#     663
# --> 664         fill_classification_arrays(feature_count, window, scaler, model, imn, Y, Y_deep, Y_max, unflatten_input=unflatten_input)
#     665
#     666         result_file = data_path+'maps/'+place+'_tile'+str(tile_id).zfill(3)+'_'+model_id+'_lulc_'+image_suffix+'.tif'
#
# /home/Peter.Kerins/UrbanLandUse/utils/util_workflow.pyc in fill_classification_arrays(feature_count, window, scaler, network, imn, Y, Y_deep, Y_max, unflatten_input)
#     552         else:
#     553             X_c_final = X_c_scaled
# --> 554         Yhat_c_prob = network.predict(X_c_final)
#     555         Yhat_c = Yhat_c_prob.argmax(axis=-1)
#     556         Yhat_max = np.amax(Yhat_c_prob,axis=-1)
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in predict(self, x, batch_size, verbose, steps)
#    1788         f = self.predict_function
#    1789         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1790                                   verbose=verbose, steps=steps)
#    1791
#    1792     def train_on_batch(self, x, y,
#
# /usr/local/lib/python2.7/dist-packages/keras/engine/training.pyc in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1297                 else:
#    1298                     ins_batch = _slice_arrays(ins, batch_ids)
# -> 1299                 batch_outs = f(ins_batch)
#    1300                 if not isinstance(batch_outs, list):
#    1301                     batch_outs = [batch_outs]
#
# /usr/local/lib/python2.7/dist-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2355         session = get_session()
#    2356         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2357                               **self.session_kwargs)
#    2358         return updated[:len(self.outputs)]
#    2359
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# KeyboardInterrupt:

# %% [markdown]
# ### View generated LULC tile (and source image)

# %%
util_workflow.view_results_overlay(data_path, place, 10, model_id, image_suffix, show_vir=True, show_lulc=True)
# Out:
# /data/phase_iii/hyderabad/maps/hyderabad_tile010_cnn_demo_1_lulc_P.tif
# 0 51555 Open Space
# 1 11288 Non-Residential
# 2 1751 Residential Atomistic
# 3 942 Residential Informal Subdivision
# 254 17408 No Data
# 0 0 255
# 1 0 255
# 2 0 244
